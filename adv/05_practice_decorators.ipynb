# %% [markdown]
# <div style="text-align: center; padding: 30px 10px;">
#
# <h1 style="color:#ff7500; font-size: 24px; margin-bottom: 10px;">
# МФТИ ФПМИ
# </h1>
#
# <h2 style="font-size: 30px; margin-top: 5px;">
# Практикум Python - Продвинутый Поток
# </h2>
#
# <hr style="width: 60%; border: 1px solid #10069f; margin: 25px auto;">
#
# <h3 style="font-size: 36px;">
# 5. Декораторы: практика
# </h3>
#
# <p style="margin-top: 20px;">
# <strong>Дата:</strong> 03-05 марта 2026 года<br>
# </p>
#
# <p style="margin-top: 25px;">
# Данный ноутбук является частью серии семинаров по курсу
# <em>«Практикум Python»</em> и предназначен для учебных и образовательных целей.
# </p>
#
# </div>

# %% [markdown]
# ## Задача 1.
# Напиши **функцию (замыкание)** `get_formula`, которая принимает на вход коэффициенты a и b, а на выход возвращает функцию, которая считает от точки $ax^2 + by^2$

# %%
# TODO

# %% [markdown]
# ## Задача 2. Декоратор для трассировки возвращаемого значения
#
# **Условие:** Написать декоратор `trace`, который выводит сообщение:
# `Функция <имя_функции> вернула значение <значение>`
# после вызова функции.

# %%
# TODO

# %% [markdown]
# ## Задача 3. Декоратор с повторными попытками выполнения (retry)
#
# - **Условие:** Написать параметризованный декоратор `retry(attempts, delay)`, который при возникновении исключения повторяет вызов функции. При неудачной попытке выводится сообщение:
# `Попытка <номер_попытки> завершилась неудачей: <сообщение_исключения>. Повтор через <delay> сек...`
#
# - Если функция не выполнится успешно после заданного числа попыток – выбрасывается последнее исключение.

# %%
# TODO

# %% [markdown]
# ## Задача 4. Регистрация команд с использованием декоратора
#
# - **Условие:** Написать декоратор `register_command`, регистрирующий функции в глобальном реестре команд, и функцию `run_command(name)` для вызова зарегистрированных функций.
#
# - Он должен хранить названия команд в глобальной переменной `command_registry` - неком словаре.

# %%
# TODO

# %% [markdown]
# Для задач 5 - 8 мы работаем с геометрическими фигурами, к которым хотим добавить работу с цветом.
#
# ```
# class Point:
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y
#
#
# class Segment:
#     def __init__(self, st, end):
#         self.st = st
#         self.end = end
# ```
# ## Задача 5.
# Напиши **функцию** `color_everyone` для классов, которая на вход получает класс, а на выход возвращает его же, но добавляет:
# - атрибут **класса** color, который по дефолту проставляется "red"
# - метод `__repr__`, который выводит строку вида "red triangle" или "orange point"
#
# Сделай функцию декоратором.

# %%
# TODO

# %% [markdown]
# ## Задача 6.
# Напиши **декоратор** `add_color`, который мы будем писать перед __init__ произвольного класса, который будет добавлять атрибут *объектам* color. По дефолту этот атрибут будет "red".

# %%
# TODO

# %% [markdown]
# ## Задача 7.
# Напиши **декоратор** `colored`, который мы будем писать перед классом; он должен изменить __init__ аналогично задаче 2.

# %%
# TODO

# %% [markdown]
# ## Задача 8.
# Переделай **декоратор** `colored` так, чтобы он принимал на вход параметр - дефолтное значение цвета.

# %%
# TODO

# %% [markdown]
# ## Задача 9.
# Напиши декоратор `singleton`.
#
# Будет ли он работать:
# - при наследовании?
# - с классовыми методами?

# %%
# TODO

# %% [markdown]
# ## Задача 10.
# Напиши **декоратор** `hide`, который мы будем писать перед классом; он принимает на вход атрибуты, которые надо сделать приватными (добавить два нижних подчёркивания перед ними).

# %%
# TODO

# %% [markdown]
# ## Задача 11.
# Напиши **декоратор** `hide_all` БЕЗ использования модуля `inspect`, который мы будем писать перед классом; он сделает все атрибуты, которые есть у объекта после `__init__` приватными.
#
# HINT: используй функцию `callable(obj)`.

# %%
# TODO

# %% [markdown]
# ## Задача 12.
# Напиши **декоратор** `my_abstract`, который добавляет поле `__is_abstract=True` к методу класса и функцию `is_abstract(obj)`, которая принимает на вход класс и проверяет, есть ли у него методы с `__is_abstract=True`.
#
# HINT: используй функцию `callable(obj)`.

# %%
# TODO
